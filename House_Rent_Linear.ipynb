# %% [markdown]
# ## Import all the libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel(r'House_Rent_Dataset.xlsx')

# %%
data
# Out:
#       Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0    2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1    2022-05-13    2  20000   800       1 out of 3   Super Area
# 2    2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3    2022-07-04    2  10000   800       1 out of 2   Super Area
# 4    2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...         ...  ...    ...   ...              ...          ...
# 4741 2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742 2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743 2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744 2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745 2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   datetime64[ns]
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: datetime64[ns](1), int64(4), object(7)
# memory usage: 445.1+ KB

# %%
data.describe(include = 'all')
# Out:
#                             Posted On          BHK          Rent         Size  \
# count                            4746  4746.000000  4.746000e+03  4746.000000
# unique                            NaN          NaN           NaN          NaN
# top                               NaN          NaN           NaN          NaN
# freq                              NaN          NaN           NaN          NaN
# mean    2022-06-07 18:01:40.126422272     2.083860  3.499345e+04   967.490729
# min               2022-04-13 00:00:00     1.000000  1.200000e+03    10.000000
# 25%               2022-05-20 00:00:00     2.000000  1.000000e+04   550.000000
# 50%               2022-06-10 00:00:00     2.000000  1.600000e+04   850.000000
# 75%               2022-06-28 00:00:00     3.000000  3.300000e+04  1200.000000
# max               2022-07-11 00:00:00     6.000000  3.500000e+06  8000.000000
# std                               NaN     0.832256  7.810641e+04   634.202328
#
# ...

# %% [markdown]
# ## Check The Duplicated Value

# %%
print("No of duplicate records - ",data.duplicated().sum())
print("% of Duplicate records - " , data.duplicated().sum()/len(data)*100)
# Out:
# No of duplicate records -  0
# % of Duplicate records -  0.0

# %% [markdown]
# ## Check the Value Counts

# %%
data['Bathroom'].value_counts()
# Out:
# Bathroom
# 2     2291
# 1     1474
# 3      749
# 4      156
# 5       60
# 6       12
# 7        3
# 10       1
# Name: count, dtype: int64

# %%
data['Size'].value_counts()
# Out:
# Size
# 1000    240
# 600     225
# 800     220
# 1200    193
# 500     192
#        ...
# 933       1
# 1838      1
# 1275      1
# 1285      1
# 2235      1
# Name: count, Length: 615, dtype: int64

# %%
data['Rent'].value_counts()
# Out:
# Rent
# 15000    275
# 10000    248
# 12000    238
# 20000    175
# 8000     162
#         ...
# 1200       1
# 5400       1
# 12333      1
# 21467      1
# 5800       1
# Name: count, Length: 243, dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
num_cols = ['BHK', 'Size', 'Bathroom']

sns.pairplot(
    data,
    x_vars=num_cols,
    y_vars=['Rent'],
    kind='reg'
)

plt.show();

# %% [markdown]
# PairPlot comparing BHK, Size, and Bathroom with Rent

# %%
data['Floor'].value_counts()
# Out:
# Floor
# 1 out of 2         379
# Ground out of 2    350
# 2 out of 3         312
# 2 out of 4         308
# 1 out of 3         293
#                   ...
# 1 out of 11          1
# 6 out of 29          1
# 28 out of 31         1
# 1 out of 15          1
# 2 out of 11          1
# Name: count, Length: 480, dtype: int64

# %%
data['Area Type'].value_counts()
# Out:
# Area Type
# Super Area     2446
# Carpet Area    2298
# Built Area        2
# Name: count, dtype: int64

# %%
data['Furnishing Status'].value_counts()
# Out:
# Furnishing Status
# Semi-Furnished    2251
# Unfurnished       1815
# Furnished          680
# Name: count, dtype: int64

# %%
data['Tenant Preferred'].value_counts()
# Out:
# Tenant Preferred
# Bachelors/Family    3444
# Bachelors            830
# Family               472
# Name: count, dtype: int64

# %%
data['Point of Contact'].value_counts()
# Out:
# Point of Contact
# Contact Owner      3216
# Contact Agent      1529
# Contact Builder       1
# Name: count, dtype: int64

# %%
data.isnull().sum()
# Out:
# Posted On            0
# BHK                  0
# Rent                 0
# Size                 0
# Floor                0
# Area Type            0
# Area Locality        0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# Point of Contact     0
# dtype: int64

# %%
data['City'].value_counts()
# Out:
# City
# Mumbai       972
# Chennai      891
# Bangalore    886
# Hyderabad    868
# Delhi        605
# Kolkata      524
# Name: count, dtype: int64

# %%
data['Area Locality'].value_counts()
# Out:
# Area Locality
# Bandra West                      37
# Gachibowli                       29
# Electronic City                  24
# Velachery                        22
# Miyapur, NH 9                    22
#                                  ..
# Magnolia Prestige, Rajarhat       1
# Dum Dum Heights, Jessore Road     1
# Shrachi Village, Madhyam Gram     1
# VIP Road Haldiram                 1
# Chak Thakurani, Thakurpukur       1
# Name: count, Length: 2235, dtype: int64

# %% [markdown]
# ## All the Unique Values in Object Data type

# %%
for feat in data.select_dtypes('object'):
    print(f'"{feat}" has {len(data[feat].unique())} unique values or {(len(data[feat].unique())/data.shape[0])*100:.2f}% of total values')
# Out:
# "Floor" has 480 unique values or 10.11% of total values
# "Area Type" has 3 unique values or 0.06% of total values
# "Area Locality" has 2235 unique values or 47.09% of total values
# "City" has 6 unique values or 0.13% of total values
# "Furnishing Status" has 3 unique values or 0.06% of total values
# "Tenant Preferred" has 3 unique values or 0.06% of total values
# "Point of Contact" has 3 unique values or 0.06% of total values

# %%
df=data.copy()
df
# Out:
#       Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0    2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1    2022-05-13    2  20000   800       1 out of 3   Super Area
# 2    2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3    2022-07-04    2  10000   800       1 out of 2   Super Area
# 4    2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...         ...  ...    ...   ...              ...          ...
# 4741 2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742 2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743 2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744 2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745 2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %% [markdown]
# ## Floor Feature Engineering

# %%
import numpy as np

def parse_floor2(x):
    x = str(x).strip().lower()

    # Case: "x out of y"
    if "out of" in x:
        left, right = x.split("out of")
        left, right = left.strip(), right.strip()

        # current floor
        if "ground" in left:
            curr = 0
        elif "basement" in left:
            curr = -1
        elif left.isdigit():
            curr = int(left)
        else:
            curr = np.nan

        # total floors
        max_floor = int(right) if right.isdigit() else np.nan

        return curr, max_floor

    # Case: single value
    if "ground" in x:
        return 0, np.nan
    elif "basement" in x:
        return -1, np.nan
    elif x.isdigit():
        return int(x), np.nan
    else:
        return np.nan, np.nan

# %%
df[['current_flat', 'max_floors']] = (df['Floor'].apply(lambda v: pd.Series(parse_floor2(v))).astype('Int64'))

# %%
df
# Out:
#       Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0    2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1    2022-05-13    2  20000   800       1 out of 3   Super Area
# 2    2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3    2022-07-04    2  10000   800       1 out of 2   Super Area
# 4    2022-05-09    2   7500   850       1 out of 2  Carpet Area
# ...         ...  ...    ...   ...              ...          ...
# 4741 2022-05-18    2  15000  1000       3 out of 5  Carpet Area
# 4742 2022-05-15    3  29000  2000       1 out of 4   Super Area
# 4743 2022-07-10    3  35000  1750       3 out of 5  Carpet Area
# 4744 2022-07-06    3  45000  1500     23 out of 34  Carpet Area
# 4745 2022-05-04    2  15000  1000       4 out of 5  Carpet Area
#
#                  Area Locality       City Furnishing Status  Tenant Preferred  \
# 0                       Bandel    Kolkata       Unfurnished  Bachelors/Family
# ...

# %% [markdown]
# ## Drop the Unnecessary Columns

# %%
df.drop(columns=['Floor'], inplace=True)
df.drop(columns=['Posted On','Point of Contact','Area Locality'],inplace=True)

# %%
df
# Out:
#       BHK   Rent  Size    Area Type       City Furnishing Status  \
# 0       2  10000  1100   Super Area    Kolkata       Unfurnished
# 1       2  20000   800   Super Area    Kolkata    Semi-Furnished
# 2       2  17000  1000   Super Area    Kolkata    Semi-Furnished
# 3       2  10000   800   Super Area    Kolkata       Unfurnished
# 4       2   7500   850  Carpet Area    Kolkata       Unfurnished
# ...   ...    ...   ...          ...        ...               ...
# 4741    2  15000  1000  Carpet Area  Hyderabad    Semi-Furnished
# 4742    3  29000  2000   Super Area  Hyderabad    Semi-Furnished
# 4743    3  35000  1750  Carpet Area  Hyderabad    Semi-Furnished
# 4744    3  45000  1500  Carpet Area  Hyderabad    Semi-Furnished
# 4745    2  15000  1000  Carpet Area  Hyderabad       Unfurnished
#
#       Tenant Preferred  Bathroom  current_flat  max_floors
# 0     Bachelors/Family         2             0           2
# 1     Bachelors/Family         1             1           3
# ...

# %% [markdown]
# ## Data Encoding

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in ['City']:
    df[col] = df[col].astype(str)  # convert all values to string
    df[col] = le.fit_transform(df[col])
    
le_name_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
print('Feature', col)
print('mapping', le_name_mapping)
# Out:
# Feature City
# mapping {'Bangalore': np.int64(0), 'Chennai': np.int64(1), 'Delhi': np.int64(2), 'Hyderabad': np.int64(3), 'Kolkata': np.int64(4), 'Mumbai': np.int64(5)}

# %%
#

# %%
df['City'].value_counts()
# Out:
# City
# 5    972
# 1    891
# 0    886
# 3    868
# 2    605
# 4    524
# Name: count, dtype: int64

# %%
df['Area Type'] = df['Area Type'].map({'Super Area':1,'Carpet Area':2,'Built Area':3})
df
# Out:
#       BHK   Rent  Size  Area Type  City Furnishing Status  Tenant Preferred  \
# 0       2  10000  1100          1     4       Unfurnished  Bachelors/Family
# 1       2  20000   800          1     4    Semi-Furnished  Bachelors/Family
# 2       2  17000  1000          1     4    Semi-Furnished  Bachelors/Family
# 3       2  10000   800          1     4       Unfurnished  Bachelors/Family
# 4       2   7500   850          2     4       Unfurnished         Bachelors
# ...   ...    ...   ...        ...   ...               ...               ...
# 4741    2  15000  1000          2     3    Semi-Furnished  Bachelors/Family
# 4742    3  29000  2000          1     3    Semi-Furnished  Bachelors/Family
# 4743    3  35000  1750          2     3    Semi-Furnished  Bachelors/Family
# 4744    3  45000  1500          2     3    Semi-Furnished            Family
# 4745    2  15000  1000          2     3       Unfurnished         Bachelors
#
#       Bathroom  current_flat  max_floors
# ...

# %%
df['Furnishing Status'] = df['Furnishing Status'].map({'Semi-Furnished':1,'Unfurnished':2,'Furnished':3})
df
# Out:
#       BHK   Rent  Size  Area Type  City  Furnishing Status  Tenant Preferred  \
# 0       2  10000  1100          1     4                  2  Bachelors/Family
# 1       2  20000   800          1     4                  1  Bachelors/Family
# 2       2  17000  1000          1     4                  1  Bachelors/Family
# 3       2  10000   800          1     4                  2  Bachelors/Family
# 4       2   7500   850          2     4                  2         Bachelors
# ...   ...    ...   ...        ...   ...                ...               ...
# 4741    2  15000  1000          2     3                  1  Bachelors/Family
# 4742    3  29000  2000          1     3                  1  Bachelors/Family
# 4743    3  35000  1750          2     3                  1  Bachelors/Family
# 4744    3  45000  1500          2     3                  1            Family
# 4745    2  15000  1000          2     3                  2         Bachelors
#
#       Bathroom  current_flat  max_floors
# ...

# %%
df['Tenant Preferred'] = df['Tenant Preferred'].map({'Bachelors/Family':1,'Bachelors':2,'Family':3})
df
# Out:
#       BHK   Rent  Size  Area Type  City  Furnishing Status  Tenant Preferred  \
# 0       2  10000  1100          1     4                  2                 1
# 1       2  20000   800          1     4                  1                 1
# 2       2  17000  1000          1     4                  1                 1
# 3       2  10000   800          1     4                  2                 1
# 4       2   7500   850          2     4                  2                 2
# ...   ...    ...   ...        ...   ...                ...               ...
# 4741    2  15000  1000          2     3                  1                 1
# 4742    3  29000  2000          1     3                  1                 1
# 4743    3  35000  1750          2     3                  1                 1
# 4744    3  45000  1500          2     3                  1                 3
# 4745    2  15000  1000          2     3                  2                 2
#
#       Bathroom  current_flat  max_floors
# ...

# %%
df.columns
# Out:
# Index(['BHK', 'Rent', 'Size', 'Area Type', 'City', 'Furnishing Status',
#        'Tenant Preferred', 'Bathroom', 'current_flat', 'max_floors'],
#       dtype='object')

# %% [markdown]
# ## EDA

# %%
# Rent cha distribution (Histogram)
plt.figure(figsize=(10, 5))
sns.histplot(df['Rent'], bins=30, kde=True, color='blue')
plt.title('Rent Distribution')
plt.show()

# %%
#  Rent vs Size (Scatter Plot)
# He check karnyasaathi ki ghar motha aslyaas rent vaadhto ka
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Size', y='Rent', data=df, hue='BHK')
plt.title('Rent vs Size (Colored by BHK)')
plt.show()

# %%
#  City-wise Rent (Box Plot)
# Kontya city madhe mahag ghare ahet?
plt.figure(figsize=(12, 6))
sns.barplot(x='City', y='Rent', data=df)
plt.title('Rent Distribution by City')
plt.show()

# %% [markdown]
# ## Insights
#
# ### City Codes
# - 0: Bangalore
# - 1: Chennai
# - 2: Delhi
# - 3: Hyderabad
# - 4: Kolkata
# - 5: Mumbai
#
# ### Key Observations
# - **Mumbai (Premium Market):** Mumbai is the most significant outlier with an average rent (~80,000) that is more than double most other cities.
# - **Kolkata (Affordable Market):** Kolkata is the most budget-friendly city with the lowest average rent and highest price stability.
# - **Market Volatility:** Cities like Mumbai and Bangalore show high price variance (large error bars), suggesting a diverse mix of both "affordable" and "ultra-luxury" housing in those hubs.

# %%
# Furnishing Status vs Rent
sns.barplot(x='Furnishing Status', y='Rent', data=df)
plt.title('Average Rent by Furnishing Status')
plt.show()

# %% [markdown]
# ### Business Insight: Furnishing Status vs. Rent
#
# - **Furnished = Highest Rent:**
#   Fully furnished houses have the **highest rent (above 50,000)** because people prefer ready-to-move-in homes, especially for luxury or office-related stays.
#
# - **Small Upgrades, Big Value:**
#   Changing a house from **Unfurnished to Semi-Furnished** increases rent a lot. This shows that even basic things like cupboards or fixtures add good value.
#
# - **Unfurnished = Stable & Budget-Friendly:**
#   Unfurnished homes have **very stable and predictable rent**, making them a good option for budget-focused tenants.

# %%
# Area Type vs Rent
sns.barplot(x='Area Type', y='Rent', data=df)
plt.title('Average Rent by Area Type')
plt.show()

# %% [markdown]
# ### Business Insight: Area Type vs. Rent
#
# - **Carpet Area = High Rent:**
#   Houses listed using **Carpet Area** usually have the **highest rent (above 50,000)**. This means luxury or premium properties mostly use carpet area for listing.
#
# - **Built Area = Low Rent:**
#   **Built Area** properties have the **lowest rent**, so they are more affordable and suitable for budget tenants.
#
# - **Super Area = Stable Pricing:**
#   **Super Area** listings have almost the **same rent across properties**, showing fixed and standardized pricing with very little variation.

# %%
# Area Type vs Rent
sns.barplot(x='Tenant Preferred', y='Rent', data=df)
plt.title('Average Rent by Furnishing Status')
plt.show()

# %% [markdown]
# ### Business Insight: Tenant Preference vs. Rent
#
# - **Families = Higher Rent:**
#   Houses preferred by **families** usually earn the **highest rent (up to 50,000)**, so family housing is a premium segment.
#
# - **Bachelors = Price Fluctuation:**
#   Rentals for **bachelors** show **big price differences**, meaning rent changes a lot depending on location and building facilities.
#
# - **Bachelors/Family = Stable & Affordable:**
#   Houses open to **both bachelors and families** have the **lowest and most stable rent**, making them affordable and easy to rent out.

# %%
#  City-wise Rent (Box Plot)
# Kontya city madhe mahag ghare ahet?
plt.figure(figsize=(12, 6))
sns.barplot(x='City', y='Size', data=df)
plt.title('Size Distribution by City')
plt.show()

# %% [markdown]
# ### City Codes
# - 0: Bangalore
# - 1: Chennai
# - 2: Delhi
# - 3: Hyderabad
# - 4: Kolkata
# - 5: Mumbai
#
# ### Business Insight: Property Size by City
#
# - **Hyderabad = Biggest Homes:**
#   Hyderabad has the **largest average house size (around 1,200 sq. ft.)**, showing a preference for spacious homes and villas.
#
# - **Mumbai = Expensive but Smaller:**
#   Mumbai has **very high rent**, but the **house size is smaller (around 900 sq. ft.)**, meaning people pay more for less space.
#
# - **Chennai & Bangalore = Similar Sizes:**
#   Chennai and Bangalore have **almost the same average house size (about 1,000 sq. ft.)**, showing a standard mid-sized housing trend in IT cities.
#
# - **Delhi & Kolkata = Compact Homes:**
#   Delhi and Kolkata have the **smallest house sizes (below 800 sq. ft.)**, indicating more compact apartments and dense urban areas.

# %%
#  Correlation Heatmap
# Kontya goshti Rent var jaast impact kartaat?
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ### Business Insight: Correlation Analysis
#
# - **Main Factors Affecting Rent:**
#   Rent increases mainly with **more bathrooms, bigger house size, and higher BHK**. These are the strongest reasons why rent goes up.
#
# - **Luxury Homes Scale Together:**
#   Bigger homes usually have **more rooms, more bathrooms, and more space together**. This shows that luxury features grow at the same time, not separately.
#
# - **Higher Floor = Higher Rent:**
#   Houses on **higher floors** or in **taller buildings** usually have **higher rent**, as people prefer better views, ventilation, and modern buildings.
#
# - **Furnishing Has Limited Impact Overall:**
#   Furnishing alone does not strongly affect rent across all properties. While it adds comfort, it does not directly increase rent in proportion to house size.
#
# - **City Matters:**
#   The **city** plays an important role in rent pricing. Even for similar houses, rent changes based on the city, acting like a base price factor.

# %%
df.dropna(subset=['max_floors','current_flat'], inplace=True)

# %%
df.columns
# Out:
# Index(['BHK', 'Rent', 'Size', 'Area Type', 'City', 'Furnishing Status',
#        'Tenant Preferred', 'Bathroom', 'current_flat', 'max_floors'],
#       dtype='object')

# %%
X = df.select_dtypes(include=[np.number]).drop(columns=["Rent"]).astype(float)
X
# Out:
#       BHK    Size  Area Type  City  Furnishing Status  Tenant Preferred  \
# 0     2.0  1100.0        1.0   4.0                2.0               1.0
# 1     2.0   800.0        1.0   4.0                1.0               1.0
# 2     2.0  1000.0        1.0   4.0                1.0               1.0
# 3     2.0   800.0        1.0   4.0                2.0               1.0
# 4     2.0   850.0        2.0   4.0                2.0               2.0
# ...   ...     ...        ...   ...                ...               ...
# 4741  2.0  1000.0        2.0   3.0                1.0               1.0
# 4742  3.0  2000.0        1.0   3.0                1.0               1.0
# 4743  3.0  1750.0        2.0   3.0                1.0               1.0
# 4744  3.0  1500.0        2.0   3.0                1.0               3.0
# 4745  2.0  1000.0        2.0   3.0                2.0               2.0
#
#       Bathroom  current_flat  max_floors
# 0          2.0           0.0         2.0
# ...

# %%
X.isnull().sum()
# Out:
# BHK                  0
# Size                 0
# Area Type            0
# City                 0
# Furnishing Status    0
# Tenant Preferred     0
# Bathroom             0
# current_flat         0
# max_floors           0
# dtype: int64

# %%
# X = df.select_dtypes(include=[np.number])

# %%
X
# Out:
#       BHK    Size  Area Type  City  Furnishing Status  Tenant Preferred  \
# 0     2.0  1100.0        1.0   4.0                2.0               1.0
# 1     2.0   800.0        1.0   4.0                1.0               1.0
# 2     2.0  1000.0        1.0   4.0                1.0               1.0
# 3     2.0   800.0        1.0   4.0                2.0               1.0
# 4     2.0   850.0        2.0   4.0                2.0               2.0
# ...   ...     ...        ...   ...                ...               ...
# 4741  2.0  1000.0        2.0   3.0                1.0               1.0
# 4742  3.0  2000.0        1.0   3.0                1.0               1.0
# 4743  3.0  1750.0        2.0   3.0                1.0               1.0
# 4744  3.0  1500.0        2.0   3.0                1.0               3.0
# 4745  2.0  1000.0        2.0   3.0                2.0               2.0
#
#       Bathroom  current_flat  max_floors
# 0          2.0           0.0         2.0
# ...

# %%
y
# Out:
# 0       10000
# 1       20000
# 2       17000
# 3       10000
# 4        7500
#         ...
# 4741    15000
# 4742    29000
# 4743    35000
# 4744    45000
# 4745    15000
# Name: Rent, Length: 4742, dtype: int64

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data=pd.DataFrame()
vif_data['feature']=X.columns
vif_data['VIF']=[variance_inflation_factor(X.values,i)for i in range(X.shape[1])]

# %%
vif_data
# Out:
#              feature        VIF
# 0                BHK  20.428669
# 1               Size   8.474386
# 2          Area Type   9.747895
# 3               City   3.800176
# 4  Furnishing Status   5.150547
# 5   Tenant Preferred   5.663174
# 6           Bathroom  21.270178
# 7       current_flat   5.283724
# 8         max_floors   6.480449

# %%
fig, ax = plt.subplots(figsize=(15,  8))
sns.heatmap(df.corr().round(2), annot=True, ax=ax)
fig.tight_layout()

# %%
sns.distplot(y)
plt.show()

# %%
 import scipy.stats as stats
stats.skew(y)
# Out:
# np.float64(21.395038479513467)

# %%
import numpy as np

y_log = np.log1p(y)  # log1p handles zeros safely

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler

# %%
# 1. X and y
X = df.drop(columns=["Rent"])
y = df["Rent"]

# 2. train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y_log, test_size=0.2, random_state=42)

# Linear Regression with scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
Decision_tree=DecisionTreeRegressor()
Decision_tree.fit(X_train_scaled,y_train)
# Out:
# DecisionTreeRegressor()

# %%
Y_pred_dc=Decision_tree.predict(X_test_scaled)

# %%
print("Decision Tree:")
print("RMSE:", np.sqrt(mean_squared_error(y_test, Y_pred_dc)))
print("MAE:", mean_absolute_error(y_test, Y_pred_dc))
r2=r2_score(y_test, Y_pred_dc)
print("R-squared:",r2)
adjusted_r_squared = 1 - (1-r2)*(len(y)-1)/(len(y)-X.shape[1]-1)
print("Adj R-square:",adjusted_r_squared)
# Out:
# Decision Tree:
# RMSE: 0.5772118307440783
# MAE: 0.4153267992480598
# R-squared: 0.6240263007445063
# Adj R-square: 0.6233112197442316

# %%
Decision_treenormal=DecisionTreeRegressor()
Decision_treenormal.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
Y_pred_dc_nor=Decision_treenormal.predict(X_test)

# %%
print("Decision Tree:")
print("RMSE:", np.sqrt(mean_squared_error(y_test, Y_pred_dc_nor)))
print("MAE:", mean_absolute_error(y_test, Y_pred_dc_nor))
r2=r2_score(y_test, Y_pred_dc_nor)
print("R-squared:",r2)
adjusted_r_squared = 1 - (1-r2)*(len(y)-1)/(len(y)-X.shape[1]-1)
print("Adj R-square:",adjusted_r_squared)
# Out:
# Decision Tree:
# RMSE: 0.5894652308019716
# MAE: 0.41092540722072035
# R-squared: 0.6078940750387104
# Adj R-square: 0.6071483114451661

# %%
rf = RandomForestRegressor(n_estimators=200, random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

# %%
print("Decision Tree:")
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred_rf)))
print("MAE:", mean_absolute_error(y_test, y_pred_rf))
r2=r2_score(y_test, y_pred_rf)
print("R-squared:",r2)
adjusted_r_squared = 1 - (1-r2)*(len(y)-1)/(len(y)-X.shape[1]-1)
print("Adj R-square:",adjusted_r_squared)
# Out:
# Decision Tree:
# RMSE: 0.4145187084942558
# MAE: 0.31516024089761013
# R-squared: 0.8061011245685417
# Adj R-square: 0.8057323397251598

# %%
model_RandomForest=RandomForestRegressor( random_state=10, bootstrap=True)
parameter_space = {
    'n_estimators':[100,300,500,1000],       
    'max_depth':[10,15,8, 12],
    'min_samples_leaf':[1,3,4,5,6,7]
    }
from sklearn.model_selection import RandomizedSearchCV #RandomizedSearchCV
clf= RandomizedSearchCV(model_RandomForest, parameter_space, n_jobs=-1, cv=5)

# %%
clf.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(random_state=10),
#                    n_jobs=-1,
#                    param_distributions={'max_depth': [10, 15, 8, 12],
#                                         'min_samples_leaf': [1, 3, 4, 5, 6, 7],
#                                         'n_estimators': [100, 300, 500, 1000]})

# %%
print(clf.best_params_)
clf.best_score_
# Out:
# {'n_estimators': 500, 'min_samples_leaf': 4, 'max_depth': 10}
# np.float64(0.8122184908075629)

# %%
y_pred_random=clf.predict(X_test)

# %%
print("Decision Tree:")
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred_random)))
print("MAE:", mean_absolute_error(y_test, y_pred_random))
r2=r2_score(y_test, y_pred_random)
print("R-squared:",r2)
adjusted_r_squared = 1 - (1-r2)*(len(y)-1)/(len(y)-X.shape[1]-1)
print("Adj R-square:",adjusted_r_squared)
# Out:
# Decision Tree:
# RMSE: 0.4002317953410143
# MAE: 0.3037849289779387
# R-squared: 0.8192367289542329
# Adj R-square: 0.8188929272975525

# %%
clf.score(X_train,y_train)
# Out:
# 0.8828785355603103

# %%
clf.score(X_test,y_test)
# Out:
# 0.8192367289542329

# %%
from sklearn.ensemble import RandomForestRegressor

model_RandomForest = RandomForestRegressor(
     n_estimators=500,
    max_depth=10,
    min_samples_leaf=6,
    min_samples_split=10,
    max_features='sqrt',
    random_state=10
)

model_RandomForest.fit(X_train, y_train)

y_pred = model_RandomForest.predict(X_test)

# %%
model_RandomForest.score(X_test,y_test)
# Out:
# 0.8167266600009522

# %%
model_RandomForest.score(X_train,y_train)
# Out:
# 0.8496420580330646

# %%
from sklearn.model_selection import cross_val_score

cv_r2 = cross_val_score(
    model_RandomForest,
    X_train,
    y_train,
    cv=5,
    scoring='r2'
)

print("CV R2 Mean:", cv_r2.mean())
# Out:
# CV R2 Mean: 0.8066666200962513

# %% [markdown]
# ## Final Business Recommendations & Insights
#
# ### 1. Priority Markets for Investment
# - **Mumbai** is the strongest market for rental income.
# - Even though properties in Mumbai are smaller in size, they generate **much higher rent**, making it a high-yield investment location.
#
# ### 2. Focus on Luxury Segments
# - Properties with **more Bathrooms and higher BHK counts** earn significantly higher rent.
# - These factors impact rent more strongly than just increasing the total square footage.
#
# ### 3. Increase Value Through Furnishing
# - Moving a property from **Unfurnished → Semi-Furnished or Furnished** leads to a large increase in rent.
# - Providing basic move-in-ready amenities is a cost-effective way to improve ROI.
# - This strategy works best for the **Family tenant segment**, which pays the highest premium.
#
# ### 4. Area Type–Based Pricing Strategy
# - Use **Carpet Area** for premium and luxury listings to justify higher pricing.
# - **Built Area** listings are better suited for budget-focused and high-volume rental markets.
#
# ### 5. Optimize for High-Rise Living
# - Properties on **higher floors** and in buildings with more total floors command higher rents.
# - Marketing should highlight features like **top-floor units, views, and modern high-rise living**.
